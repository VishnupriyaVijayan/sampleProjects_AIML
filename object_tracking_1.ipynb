# %%
import cv2
import time
import imutils

firstFrame = None
area = 100

cam = cv2.VideoCapture(0)

while True:
    _, img = cam.read()
    text = "Normal"
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussianImg = cv2.GaussianBlur(grayImg, (21, 21), 0)

    if firstFrame is None:
        firstFrame = gaussianImg
        continue

    imgDiff = cv2.absdiff(firstFrame, gaussianImg)
    threshImg = cv2.threshold(imgDiff, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)

    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)

    object_count = 0  # Reset the count for each frame

    for c in cnts:
        if cv2.contourArea(c) < area:
            continue
        (x, y, w, h) = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        text = "Moving Object detected"
        object_count += 1

    print(f"{text} - {object_count} objects detected")

    cv2.putText(img, f"{text} - {object_count} objects", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (250, 0, 100), 2)

    cv2.imshow("cameraFeed", img)

    key = cv2.waitKey(1)
    if key == ord("q"):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# Moving Object detected - 9 objects detected
# Moving Object detected - 9 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# Moving Object detected - 2 objects detected
# ...

# %%
import cv2
import time
import imutils

firstFrame = None
area = 100

cam = cv2.VideoCapture('cars_on_highway.mp4')

if not cam.isOpened():
    print("Error: Unable to open the video file.")
    exit()

ret, img = cam.read()
if not ret:
    print("Error: Unable to read the first frame from the video.")
    exit()

while ret:
    ret, img = cam.read()
    if not ret:
        print("Error: Unable to read the next frame from the video.")
        break

    text = "Normal"
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussianImg = cv2.GaussianBlur(grayImg, (21, 21), 0)

    if firstFrame is None:
        firstFrame = gaussianImg
        continue

    imgDiff = cv2.absdiff(firstFrame, gaussianImg)
    threshImg = cv2.threshold(imgDiff, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)

    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)

    object_count = 0  # Reset the count for each frame

    for c in cnts:
        if cv2.contourArea(c) < area:
            continue
        (x, y, w, h) = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        text = "Moving Object detected"
        object_count += 1

    print(f"{text} - {object_count} objects detected")

    cv2.putText(img, f"{text} - {object_count} objects", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (250, 0, 100), 2)

    cv2.imshow("cameraFeed", img)

    key = cv2.waitKey(1)
    if key == ord("q"):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# Moving Object detected - 8 objects detected
# Moving Object detected - 9 objects detected
# Moving Object detected - 7 objects detected
# Moving Object detected - 12 objects detected
# Moving Object detected - 12 objects detected
# Moving Object detected - 14 objects detected
# Moving Object detected - 12 objects detected
# Moving Object detected - 14 objects detected
# Moving Object detected - 11 objects detected
# Moving Object detected - 6 objects detected
# Moving Object detected - 6 objects detected
# Moving Object detected - 9 objects detected
# Moving Object detected - 6 objects detected
# Moving Object detected - 10 objects detected
# Moving Object detected - 11 objects detected
# Moving Object detected - 12 objects detected
# Moving Object detected - 12 objects detected
# Moving Object detected - 13 objects detected
# Moving Object detected - 11 objects detected
# Moving Object detected - 8 objects detected
# Moving Object detected - 7 objects detected
# ...
