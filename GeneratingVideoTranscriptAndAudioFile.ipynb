# %% [raw]
# !pip install git+https://github.com/openai/whisper.git
# !pip install ffmpeg-python python-docx

# %%
import os
import ffmpeg
import whisper
from docx import Document

# %%
def extract_audio(video_path, output_audio_path):
    """
    Extracts audio from a video file.
    """
    ffmpeg.input(video_path).output(output_audio_path, ac=1, ar='16k').run(overwrite_output=True)

# %%
def transcribe_audio(audio_path, model_name="base"):
    """
    Transcribes audio using Whisper.
    """
    model = whisper.load_model(model_name)
    result = model.transcribe(audio_path)
    return result['text']

# %%
def save_to_text(transcript, output_path):
    """
    Saves the transcript to a text file.
    """
    with open(output_path, 'w') as file:
        file.write(transcript)

def save_to_word(transcript, output_path):
    """
    Saves the transcript to a Word file.
    """
    doc = Document()
    doc.add_paragraph(transcript)
    doc.save(output_path)

# %%
def process_videos(input_folder, output_folder, model_name="base"):
    """
    Processes all videos in a folder and saves the transcripts.
    """
    os.makedirs(output_folder, exist_ok=True)

    for file_name in os.listdir(input_folder):
        if file_name.endswith(('.mp4', '.avi', '.mkv')):  # Add other video formats as needed
            video_path = os.path.join(input_folder, file_name)
            audio_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.wav")
            text_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.txt")
            word_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.docx")

            # Extract audio
            print(f"Extracting audio from {file_name}...")
            extract_audio(video_path, audio_path)
            
            # Transcribe audio
            print(f"Transcribing {file_name}...")
            transcript = transcribe_audio(audio_path, model_name=model_name)
            
            # Save transcripts
            print(f"Saving transcript for {file_name}...")
            save_to_text(transcript, text_path)
            save_to_word(transcript, word_path)

# %%
input_folder = r"F:\Jupyter_Notebook\NLP_Internshala\Getting Started with NLP (1)\Getting Started with NLP"  # Replace with the path to your video files
output_folder = r"F:\Jupyter_Notebook\NLP_Internshala\Getting Started with NLP (1)\Getting Started with NLP\Transcripts"  # Replace with the path to save transcripts

process_videos(input_folder, output_folder, model_name="base")
# Out:
# Extracting audio from M1_T1_V1_What is Natural Language Processing (NLP)_1-1.mp4...
# Transcribing M1_T1_V1_What is Natural Language Processing (NLP)_1-1.mp4...
# 100%|███████████████████████████████████████| 139M/139M [00:48<00:00, 3.01MiB/s]
# C:\Users\vishn\anaconda3\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Saving transcript for M1_T1_V1_What is Natural Language Processing (NLP)_1-1.mp4...
# Extracting audio from M1_T1_V2_Applications of Natural Language Processing (NLP)_1-2.mp4...
# Transcribing M1_T1_V2_Applications of Natural Language Processing (NLP)_1-2.mp4...
# Saving transcript for M1_T1_V2_Applications of Natural Language Processing (NLP)_1-2.mp4...
# Extracting audio from M1_T3_V1_Text Processing_1-3.mp4...
# Transcribing M1_T3_V1_Text Processing_1-3.mp4...
# Saving transcript for M1_T3_V1_Text Processing_1-3.mp4...
# Extracting audio from M1_T3_V2_Reading Text Data_1-4.mp4...
# Transcribing M1_T3_V2_Reading Text Data_1-4.mp4...
# Saving transcript for M1_T3_V2_Reading Text Data_1-4.mp4...
# Extracting audio from M1_T3_V3_Reading Text Data 2_1-5.mp4...
# Transcribing M1_T3_V3_Reading Text Data 2_1-5.mp4...
# Saving transcript for M1_T3_V3_Reading Text Data 2_1-5.mp4...
# Extracting audio from M1_T4_V1_What are Regular Expressions__1-6.mp4...
# Transcribing M1_T4_V1_What are Regular Expressions__1-6.mp4...
# Saving transcript for M1_T4_V1_What are Regular Expressions__1-6.mp4...
# Extracting audio from M1_T4_V3_Understanding Regular Expressions 2--7.mp4...
# Transcribing M1_T4_V3_Understanding Regular Expressions 2--7.mp4...
# Saving transcript for M1_T4_V3_Understanding Regular Expressions 2--7.mp4...
# Extracting audio from M1_T5_V1_Regular Expressions in Python - Part I_1-8.mp4...
# Transcribing M1_T5_V1_Regular Expressions in Python - Part I_1-8.mp4...
# Saving transcript for M1_T5_V1_Regular Expressions in Python - Part I_1-8.mp4...
# Extracting audio from M1_T5_V2_Regular Expressions in Python - Part II_1-9.mp4...
# Transcribing M1_T5_V2_Regular Expressions in Python - Part II_1-9.mp4...
# Saving transcript for M1_T5_V2_Regular Expressions in Python - Part II_1-9.mp4...
# Extracting audio from M1_T5_V3_Using Regular Expressions on Real-World Dataset_1-10.mp4...
# Transcribing M1_T5_V3_Using Regular Expressions on Real-World Dataset_1-10.mp4...
# Saving transcript for M1_T5_V3_Using Regular Expressions on Real-World Dataset_1-10.mp4...
# Extracting audio from M1_T5_V4_Solution to Exercise of RegEx on real world Dataset_1-11.mp4...
# Transcribing M1_T5_V4_Solution to Exercise of RegEx on real world Dataset_1-11.mp4...
# Saving transcript for M1_T5_V4_Solution to Exercise of RegEx on real world Dataset_1-11.mp4...

# %%
import os
from pathlib import Path
import whisper

def process_videos_recursive(base_folder, model_name="base"):
    """
    Recursively process video files in subfolders and save transcripts in a 'Transcripts' folder.
    
    :param base_folder: The path to the base folder containing subfolders with videos.
    :param model_name: Whisper model name to use for transcription (e.g., "base", "small", "medium").
    """
    # Load the Whisper model
    model = whisper.load_model(model_name)
    
    # Walk through the base folder recursively
    for root, dirs, files in os.walk(base_folder):
        # Find video files in the current folder
        video_files = [f for f in files if f.lower().endswith(('.mp4', '.avi', '.mov', '.mkv', '.flv'))]
        
        if video_files:
            # Create a 'Transcripts' folder in the current subfolder
            transcript_folder = Path(root) / "Transcripts"
            transcript_folder.mkdir(exist_ok=True)
            
            for video_file in video_files:
                video_path = Path(root) / video_file
                transcript_path = transcript_folder / f"{video_file}.txt"
                
                # Skip transcription if the transcript already exists
                if transcript_path.exists():
                    print(f"Skipping {video_path} (transcript already exists).")
                    continue
                
                print(f"Processing {video_path}...")
                try:
                    # Transcribe the video
                    result = model.transcribe(str(video_path))
                    
                    # Save the transcript
                    with open(transcript_path, "w", encoding="utf-8") as f:
                        f.write(result["text"])
                    
                    print(f"Transcript saved: {transcript_path}")
                except Exception as e:
                    print(f"Error processing {video_path}: {e}")

# Base folder containing your subfolders with videos
base_folder = r"F:\Jupyter_Notebook\NLP_Internshala\classVideos"
process_videos_recursive(base_folder, model_name="base")
# Out:
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T1_V1_Introduction to Feature Engineering for Text Data_1-58.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T1_V1_Introduction to Feature Engineering for Text Data_1-58.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T2_V1_Text Feature Engineering Techniques_1-59.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T2_V1_Text Feature Engineering Techniques_1-59.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T2_V2_Text Feature Engineering Implementation_1-60.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T2_V2_Text Feature Engineering Implementation_1-60.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T3_V1_Text Representation_1-61.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T3_V1_Text Representation_1-61.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T3_V2_Text Representation Implementation_1-62.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T3_V2_Text Representation Implementation_1-62.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T4_V1_Word Embeddings Part 1_1-63.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T4_V1_Word Embeddings Part 1_1-63.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T4_V3_Word Embeddings Implementation Part 2_1-64.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T4_V3_Word Embeddings Implementation Part 2_1-64.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T4_V3_Word Embeddings Implementation_1-65.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T4_V3_Word Embeddings Implementation_1-65.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\M5_T4_V4_Word Embeddings Implementation Part 2_1-66.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Feature Engineering for Text Data\Feature Engineering for Text Data\Transcripts\M5_T4_V4_Word Embeddings Implementation Part 2_1-66.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T1_V1_Introduction to Information Retrieval_1-32.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T1_V1_Introduction to Information Retrieval_1-32.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T2_V1_Approaches to Information Retrieval_1-33.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T2_V1_Approaches to Information Retrieval_1-33.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T2_V2_Inverted - index_1-34.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T2_V2_Inverted - index_1-34.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T3_V1_Evaluation of Information Retrieval models_1-35.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T3_V1_Evaluation of Information Retrieval models_1-35.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T4_V1_Introduction to ranked retrieval_1-36.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T4_V1_Introduction to ranked retrieval_1-36.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T5_V1_Jaccard Coefficient_1-37.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T5_V1_Jaccard Coefficient_1-37.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T5_V2_Term-Frequency (TF)_1-38.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T5_V2_Term-Frequency (TF)_1-38.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T5_V3_Inverse Document Frequency (IDF)_1-39.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T5_V3_Inverse Document Frequency (IDF)_1-39.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T5_V4_Vector Space Model VIDEO_1-40.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T5_V4_Vector Space Model VIDEO_1-40.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T6_V1_Evaluation of ranked retrieval models_1-41.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T6_V1_Evaluation of ranked retrieval models_1-41.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T7_V1_Understanding the Problem Statement_1-42.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T7_V1_Understanding the Problem Statement_1-42.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T7_V2_Loading the Dataset and Retrieving Documents using Jaccard Coefficient_1-43.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T7_V2_Loading the Dataset and Retrieving Documents using Jaccard Coefficient_1-43.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T7_V3_Ranked Retrieval using Term Frequency (TF) and Inverse Document Frequency (IDF)_1-44.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T7_V3_Ranked Retrieval using Term Frequency (TF) and Inverse Document Frequency (IDF)_1-44.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\M3_T7_V4_Ranked Retrieval using TF-IDF and vector space model_1-45.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Information Retrieval and Ranked Retrieval\Information Retrieval and Ranked Retrieval\Transcripts\M3_T7_V4_Ranked Retrieval using TF-IDF and vector space model_1-45.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T1_V1_Introduction to Language Modeling_1-46.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T1_V1_Introduction to Language Modeling_1-46.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T1_V2_Application of Language Modeling_1-47.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T1_V2_Application of Language Modeling_1-47.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T2_V1_Probabilistic Language Modeling_1-48.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T2_V1_Probabilistic Language Modeling_1-48.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T3_V1_Evaluation of Language Modeling VIDEO_1-49.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T3_V1_Evaluation of Language Modeling VIDEO_1-49.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T4_V1_Understanding the Problem Statement VIDEO_1-50.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T4_V1_Understanding the Problem Statement VIDEO_1-50.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T4_V2_Project_ Next word Recommender System - Part I_1-51.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T4_V2_Project_ Next word Recommender System - Part I_1-51.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T4_V3_Project_ Next word Recommender System - Part II_1-52.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T4_V3_Project_ Next word Recommender System - Part II_1-52.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T5_V1_Introduction to Spelling Correction_1-53.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T5_V1_Introduction to Spelling Correction_1-53.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T5_V2_Types of Spelling Errors_1-54.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T5_V2_Types of Spelling Errors_1-54.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T5_V3_Noisy Channel Model for spelling correction_1-55.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T5_V3_Noisy Channel Model for spelling correction_1-55.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T6_V1_Loading and Pre-processing the dataset_1-56.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T6_V1_Loading and Pre-processing the dataset_1-56.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\M4_T6_V2_Building the autocorrect model_1-57.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Language Modeling\Language Modeling\Transcripts\M4_T6_V2_Building the autocorrect model_1-57.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T1_V1_Introduction to Text Classification_1-1.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T1_V1_Introduction to Text Classification_1-1.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T2_V1_Hand Coded Rules for Text Classification_1-2.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T2_V1_Hand Coded Rules for Text Classification_1-2.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T3_V1_Supervised Machine Learning for Text Classification_1-3.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T3_V1_Supervised Machine Learning for Text Classification_1-3.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T3_V2_Understanding Naive Bayes for text classification_1-4.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T3_V2_Understanding Naive Bayes for text classification_1-4.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T4_V1_Understanding Project SMS spam classification_1-5.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T4_V1_Understanding Project SMS spam classification_1-5.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T4_V2_Implementing SMS spam classifier - Part I_1-6.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T4_V2_Implementing SMS spam classifier - Part I_1-6.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T4_V3_Implementing SMS spam classifier - Part II_1-7.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T4_V3_Implementing SMS spam classifier - Part II_1-7.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T5_V1_Understanding the Problem Statement_1-8.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T5_V1_Understanding the Problem Statement_1-8.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T5_V2_Building Sentiment Analysis Model_1-9.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T5_V2_Building Sentiment Analysis Model_1-9.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T6_V1_Auto tagging stack exchange questions Part 1_1-10.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T6_V1_Auto tagging stack exchange questions Part 1_1-10.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\M6_T6_V2_Auto tagging stack exchange questions Part 2_1-11.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text classification\Text classification\Transcripts\M6_T6_V2_Auto tagging stack exchange questions Part 2_1-11.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T10_V1_Relation Extraction_1-12.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T10_V1_Relation Extraction_1-12.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T10_V2_Relation Extraction Implementation_1-13.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T10_V2_Relation Extraction Implementation_1-13.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T11_V1_Project - United Nations Debate Analysis 1_1-14.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T11_V1_Project - United Nations Debate Analysis 1_1-14.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T11_V2_Project - United Nations Debate Analysis 2_1-15.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T11_V2_Project - United Nations Debate Analysis 2_1-15.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T12_V1_Introduction to string similarity_1-16.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T12_V1_Introduction to string similarity_1-16.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T13_V1_Hamming distance to calculate string similarity_1-17.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T13_V1_Hamming distance to calculate string similarity_1-17.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T13_V2_Levenshtein distance to calculate string similarity_1-18.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T13_V2_Levenshtein distance to calculate string similarity_1-18.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T13_V3_Implementing Levenshtein distance_1-19.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T13_V3_Implementing Levenshtein distance_1-19.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T1_V1_Text Pre-processing_1-20.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T1_V1_Text Pre-processing_1-20.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T2_V1_Tokenization_1-21.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T2_V1_Tokenization_1-21.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T3_V1_Stopword Removal_1-22.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T3_V1_Stopword Removal_1-22.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T4_V1_Normalization_1-23.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T4_V1_Normalization_1-23.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T5_V1_Exploring Text Data_1-24.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T5_V1_Exploring Text Data_1-24.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T6_V1_What is information extraction_1-25.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T6_V1_What is information extraction_1-25.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T7_V1_Part-of-Speech (POS) tagging_1-26.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T7_V1_Part-of-Speech (POS) tagging_1-26.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T7_V2_POS Tags Implementation_1-27.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T7_V2_POS Tags Implementation_1-27.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T8_V1_Dependency Parsing_1-28.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T8_V1_Dependency Parsing_1-28.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T8_V2_Dependency Parsing Implementation_1-29.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T8_V2_Dependency Parsing Implementation_1-29.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T9_V1_Named Entity Recognition (NER)_1-30.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T9_V1_Named Entity Recognition (NER)_1-30.mp4.txt
# Processing F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\M2_T9_V2_NER Implementation_1-31.mp4...
# Transcript saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts\M2_T9_V2_NER Implementation_1-31.mp4.txt

# %%
import os
from pathlib import Path
from docx import Document

def merge_texts_to_word(input_folder, output_file):
    """
    Merge all text files in a folder into a Word document.
    
    :param input_folder: Path to the folder containing text files.
    :param output_file: Path to the output Word document.
    """
    # Create a new Word document
    document = Document()
    
    # Iterate over all text files in the input folder
    for text_file in sorted(Path(input_folder).glob("*.txt")):
        # Use the file name (without extension) as the title
        title = text_file.stem
        
        # Add the title to the Word document
        document.add_heading(title, level=1)
        
        # Read the content of the text file
        with open(text_file, "r", encoding="utf-8") as f:
            content = f.read()
        
        # Add the content to the Word document
        document.add_paragraph(content)
        document.add_paragraph("\n")  # Add a blank line for separation
    
    # Save the Word document
    document.save(output_file)
    print(f"Word document saved: {output_file}")

# Folder containing text files
input_folder = r"F:\Jupyter_Notebook\NLP_Internshala\classVideos\Getting Started with NLP (1)\Getting Started with NLP\Transcripts"

# Path for the output Word document
output_file = r"F:\Jupyter_Notebook\NLP_Internshala\classVideos\Getting Started with NLP.docx"

merge_texts_to_word(input_folder, output_file)
# Out:
# Word document saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Getting Started with NLP.docx

# %%
import os
from pathlib import Path
from docx import Document

def merge_texts_with_structure(input_folder):
    """
    Merge all text files in a folder into a Word document with chapters and subsections.
    
    :param input_folder: Path to the folder containing text files.
    """
    # Get the name of the folder to use as the output filename
    folder_name = Path(input_folder).name
   # output_file = Path(input_folder).parent / f"{folder_name}.docx"
    # Path for the output Word document
    output_file = r"F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction.docx"

    # Create a new Word document
    document = Document()
    
    # Dictionary to group files by chapters
    chapters = {}

    # Iterate over all text files in the input folder
    for text_file in sorted(Path(input_folder).glob("*.txt")):
        # Extract parts from the filename
        filename = text_file.stem
        parts = filename.split("_")
        
        # Parse chapter and subsection
        chapter = f"Chapter {parts[0][1:]}" if parts[0].startswith("M") else "Unknown Chapter"
        subsection = parts[-1] if len(parts) > 1 else "Unnamed Subsection"
        
        # Group by chapter
        if chapter not in chapters:
            chapters[chapter] = []
        chapters[chapter].append((subsection, text_file))
    
    # Add chapters and subsections to the Word document
    for chapter, subsections in sorted(chapters.items()):
        # Add chapter heading
        document.add_heading(chapter, level=1)
        
        for subsection, text_file in sorted(subsections):
            # Add subsection heading
            document.add_heading(subsection, level=2)
            
            # Read and add content of the text file
            with open(text_file, "r", encoding="utf-8") as f:
                content = f.read()
            document.add_paragraph(content)
            document.add_paragraph("\n")  # Add a blank line for separation
    
    # Save the Word document
    document.save(output_file)
    print(f"Word document saved: {output_file}")

# Folder containing text files
input_folder = r"F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction\Text Pre-processing and Information Extraction\Transcripts"

merge_texts_with_structure(input_folder)
# Out:
# Word document saved: F:\Jupyter_Notebook\NLP_Internshala\classVideos\Text Pre-processing and Information Extraction.docx
